# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mumbai.csv')
df
# Out:
#            price                                            Address    area  \
# 0     22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1     35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2     31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3     18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4     13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# ...          ...                                                ...     ...
# 6250  19500000.0   Yari Road, Mumbai - Western Suburbs, Maharashtra   810.0
# 6251  22000000.0  502., Hari Om Nagar, Mumbai - North Mumbai, Ma...  1400.0
# 6252  20000000.0  Lokhandwala Complex, Andheri West, Lokhandwala...   750.0
# 6253  11000000.0         Sion, Mumbai - Central Mumbai, Maharashtra   700.0
# 6254  15000000.0    Mulund West, Mumbai - Central Line, Maharashtra   900.0
#
#        latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0     19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1     19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2     19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3     19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4     19.177555  72.849887       2.0        2.0      NaN                 NaN
# ...         ...        ...       ...        ...      ...                 ...
# 6250  19.138320  72.810020       2.0        2.0      NaN       Ready to Move
# 6251  19.221920  72.854250       3.0        3.0      1.0       Ready to Move
# 6252  19.144320  72.824111       2.0        2.0      NaN       Ready to Move
# 6253  19.047201  72.872225       2.0        2.0      NaN       Ready to Move
# 6254  19.168818  72.936375       2.0        2.0      NaN       Ready to Move
#
#           neworold  parking Furnished_status  Lift  \
# 0     New Property      NaN              NaN   2.0
# 1     New Property      NaN              NaN   2.0
# 2     New Property      1.0              NaN   2.0
# 3     New Property      1.0              NaN   3.0
# 4     New Property      1.0      Unfurnished   2.0
# ...            ...      ...              ...   ...
# 6250        Resale      1.0   Semi-Furnished   NaN
# 6251        Resale      NaN      Unfurnished   NaN
# 6252        Resale      1.0              NaN   1.0
# 6253        Resale      NaN        Furnished   NaN
# 6254        Resale      NaN              NaN   NaN
#
#                               Landmarks type_of_building  \
# 0                                   NaN             Flat
# 1                                   NaN             Flat
# 2                                   NaN             Flat
# 3                        Laxmi Callista             Flat
# 4                near uper govind nagar             Flat
# ...                                 ...              ...
# 6250                                NaN             Flat
# 6251                                NaN             Flat
# 6252  Lokhandwala Complex, Andheri West             Flat
# 6253                                NaN             Flat
# 6254                                NaN             Flat
#
#                                                    desc    Price_sqft
# 0     \n\n\n                                Right fr...  35612.082671
# 1     \n\n\n                                Right fr...  35934.291581
# 2     \n                    \n                    \n...  32747.933884
# 3     \n\n\n                                Welcome ...  29729.729730
# 4     \n                    \n                    \n...  12385.321101
# ...                                                 ...           ...
# 6250  \n\n\n                                 This Mu...  24074.074074
# 6251  \n                    \n                    \n...  15714.285714
# 6252  \n\n\n                                 This Fr...  26666.666667
# 6253                                                 \n  15714.285714
# 6254                                                 \n  16666.666667
#
# [6255 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             6255 non-null   float64
#  1   Address           6255 non-null   object
#  2   area              6255 non-null   float64
#  3   latitude          6255 non-null   float64
#  4   longitude         6255 non-null   float64
#  5   Bedrooms          6255 non-null   float64
#  6   Bathrooms         6255 non-null   float64
#  7   Balcony           2376 non-null   float64
#  8   Status            5774 non-null   object
#  9   neworold          6255 non-null   object
#  10  parking           2129 non-null   float64
#  11  Furnished_status  3600 non-null   object
#  12  Lift              1678 non-null   float64
#  13  Landmarks         2617 non-null   object
#  14  type_of_building  6255 non-null   object
#  15  desc              6255 non-null   object
#  16  Price_sqft        6255 non-null   float64
# dtypes: float64(10), object(7)
# memory usage: 830.9+ KB

# %%
df.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1  19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2  19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3  19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0      NaN                 NaN
#
#        neworold  parking Furnished_status  Lift               Landmarks  \
# 0  New Property      NaN              NaN   2.0                     NaN
# 1  New Property      NaN              NaN   2.0                     NaN
# 2  New Property      1.0              NaN   2.0                     NaN
# 3  New Property      1.0              NaN   3.0          Laxmi Callista
# 4  New Property      1.0      Unfurnished   2.0  near uper govind nagar
#
#   type_of_building                                               desc  \
# 0             Flat  \n\n\n                                Right fr...
# 1             Flat  \n\n\n                                Right fr...
# 2             Flat  \n                    \n                    \n...
# 3             Flat  \n\n\n                                Welcome ...
# 4             Flat  \n                    \n                    \n...
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# 3  29729.729730
# 4  12385.321101

# %%
df.describe()
# Out:
#               price         area     latitude    longitude     Bedrooms  \
# count  6.255000e+03  6255.000000  6255.000000  6255.000000  6255.000000
# mean   2.684187e+07  1185.625260    19.156772    72.868642     2.452278
# std    2.788831e+07   636.973259     0.109447     0.058614     0.749534
# min    1.500000e+06   503.000000    18.873713    72.754080     2.000000
# 25%    1.300000e+07   846.500000    19.081509    72.832930     2.000000
# 50%    1.900000e+07  1000.000000    19.147269    72.858019     2.000000
# 75%    3.000000e+07  1300.000000    19.213054    72.884691     3.000000
# max    3.600000e+08  8000.000000    19.476239    73.197823    10.000000
#
#          Bathrooms      Balcony      parking         Lift     Price_sqft
# count  6255.000000  2376.000000  2129.000000  1678.000000    6255.000000
# mean      2.425580     2.162879     4.662283     2.448153   21422.923601
# std       0.762604     1.221899    35.780057     1.566455   12698.478665
# min       0.000000     1.000000     1.000000     0.000000    1500.000000
# 25%       2.000000     1.000000     1.000000     2.000000   13709.934735
# 50%       2.000000     2.000000     1.000000     2.000000   19285.714286
# 75%       3.000000     3.000000     2.000000     3.000000   26500.000000
# max      10.000000     8.000000   801.000000    10.000000  119047.619048

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             3879
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
df['Furnished_status'].unique()
# Out:
# array([nan, 'Unfurnished', 'Semi-Furnished', 'Furnished'], dtype=object)

# %%
#converting categorical data to numerical data
df['Furnished_status']= df['Furnished_status'].map({'Unfurnished':1,'Semi-Furnished':2,'Furnished':3})

# %%
df.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1  19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2  19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3  19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0      NaN                 NaN
#
#        neworold  parking  Furnished_status  Lift               Landmarks  \
# 0  New Property      NaN               NaN   2.0                     NaN
# 1  New Property      NaN               NaN   2.0                     NaN
# 2  New Property      1.0               NaN   2.0                     NaN
# 3  New Property      1.0               NaN   3.0          Laxmi Callista
# 4  New Property      1.0               1.0   2.0  near uper govind nagar
#
#   type_of_building                                               desc  \
# 0             Flat  \n\n\n                                Right fr...
# 1             Flat  \n\n\n                                Right fr...
# 2             Flat  \n                    \n                    \n...
# 3             Flat  \n\n\n                                Welcome ...
# 4             Flat  \n                    \n                    \n...
#
#      Price_sqft
# 0  35612.082671
# 1  35934.291581
# 2  32747.933884
# 3  29729.729730
# 4  12385.321101

# %%
df.drop('desc',axis=1,inplace=True) #dropping description as it is not required and has many inconsistenies in data
df.drop('Landmarks',axis=1,inplace=True) #dropping landmarks as it is not required

# %%
df.Bathrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  5.,  6.,  7.,  8., 10.,  0.])

# %%
column_names = df.columns
print(df.columns)
# Out:
# Index(['price', 'Address', 'area', 'latitude', 'longitude', 'Bedrooms',
#        'Bathrooms', 'Balcony', 'Status', 'neworold', 'parking',
#        'Furnished_status', 'Lift', 'type_of_building', 'Price_sqft'],
#       dtype='object')

# %%
df.hist(bins=50 ,figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>,
#         <Axes: title={'center': 'latitude'}>],
#        [<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>],
#        [<Axes: title={'center': 'Balcony'}>,
#         <Axes: title={'center': 'parking'}>,
#         <Axes: title={'center': 'Furnished_status'}>],
#        [<Axes: title={'center': 'Lift'}>,
#         <Axes: title={'center': 'Price_sqft'}>, <Axes: >]], dtype=object)

# %%
df.drop('Lift', axis=1, inplace=True)
df.drop('parking', axis=1, inplace=True)

df.drop('Balcony', axis=1, inplace=True) #Dropping these columns as they have high missing values and are not important for the model
df.drop('latitude', axis=1, inplace=True)
df.drop('longitude', axis=1, inplace=True) #Dropping these columns because users do not always know the exact latitude and longitude of the house

# %%
df['Status'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', nan], dtype=object)

# %%
df['Status'] = df['Status'].map({'Under Construction': 0, 'Ready to Move': 1})

# %%
df['Status'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['Status'].fillna(df['Status'].mode()[0],inplace=True)
df['Furnished_status'].fillna(df['Furnished_status'].mode()[0],inplace=True)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_14272\2445201001.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Status'].fillna(df['Status'].mode()[0],inplace=True)
# C:\Users\prath\AppData\Local\Temp\ipykernel_14272\2445201001.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Furnished_status'].fillna(df['Furnished_status'].mode()[0],inplace=True)

# %%
df['Status'].unique()
# Out:
# array([0., 1.])

# %%
df['type_of_building'].unique()
# Out:
# array(['Flat', 'Individual House'], dtype=object)

# %%
df['type_of_building'] = df['type_of_building'].map({'Flat': 1, 'Individual House': 2}) #converting categorical data to numerical data

# %%
df['type_of_building'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['Address'].nunique()
df.drop('Address', axis=1, inplace=True) #Dropping address as it is not fit for the model

# %%
num_rows = df.shape[0]
print("Number of rows in the dataframe:", num_rows)
# Out:
# Number of rows in the dataframe: 6255

# %%
df.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status      neworold  \
# 0  22400000.0   629.0       2.0        2.0     0.0  New Property
# 1  35000000.0   974.0       3.0        2.0     0.0  New Property
# 2  31700000.0   968.0       3.0        3.0     0.0  New Property
# 3  18700000.0   629.0       2.0        2.0     1.0  New Property
# 4  13500000.0  1090.0       2.0        2.0     1.0  New Property
#
#    Furnished_status  type_of_building    Price_sqft
# 0               1.0                 1  35612.082671
# 1               1.0                 1  35934.291581
# 2               1.0                 1  32747.933884
# 3               1.0                 1  29729.729730
# 4               1.0                 1  12385.321101

# %%
df['neworold'].value_counts()
# Out:
# neworold
# Resale          5515
# New Property     740
# Name: count, dtype: int64

# %%
df['neworold'] = df['neworold'].map({'New Property': 2, 'Resale': 1}) #converting categorical data to numerical data

# %%
df.columns
# Out:
# Index(['price', 'area', 'Bedrooms', 'Bathrooms', 'Status', 'neworold',
#        'Furnished_status', 'type_of_building', 'Price_sqft'],
#       dtype='object')

# %%
price= df['price']
area = df['area']
sns.relplot(kind='scatter',x='area',y='price',data=df,color='red')

# %%
sns.relplot(kind='scatter',y='price',x='Bedrooms',data=df,color='brown')

# %%
sns.relplot(kind='scatter',y='price',x='Bathrooms',data=df,color='green')

# %%
sns.relplot(kind='scatter',y='price',x='Price_sqft',data=df,color='#F72585')

# %%
correlation = df.corr()['price']
print(correlation)
# Out:
# price               1.000000
# area                0.712270
# Bedrooms            0.586444
# Bathrooms           0.639180
# Status             -0.002245
# neworold            0.037078
# Furnished_status    0.065699
# type_of_building    0.000008
# Price_sqft          0.725421
# Name: price, dtype: float64

# %%
df.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status  neworold  \
# 0  22400000.0   629.0       2.0        2.0     0.0         2
# 1  35000000.0   974.0       3.0        2.0     0.0         2
# 2  31700000.0   968.0       3.0        3.0     0.0         2
# 3  18700000.0   629.0       2.0        2.0     1.0         2
# 4  13500000.0  1090.0       2.0        2.0     1.0         2
#
#    Furnished_status  type_of_building    Price_sqft
# 0               1.0                 1  35612.082671
# 1               1.0                 1  35934.291581
# 2               1.0                 1  32747.933884
# 3               1.0                 1  29729.729730
# 4               1.0                 1  12385.321101

# %%
column_data_types = df.dtypes
print(column_data_types)
# Out:
# price               float64
# area                float64
# Bedrooms            float64
# Bathrooms           float64
# Status              float64
# neworold              int64
# Furnished_status    float64
# type_of_building      int64
# Price_sqft          float64
# dtype: object

# %%
df['Furnished_status'] = df['Furnished_status'].astype(int)
df['Bedrooms'] = df['Bedrooms'].astype(int)
df['Bathrooms'] = df['Bathrooms'].astype(int)

# %%
df.head()
# Out:
#         price    area  Bedrooms  Bathrooms  Status  neworold  \
# 0  22400000.0   629.0         2          2     0.0         2
# 1  35000000.0   974.0         3          2     0.0         2
# 2  31700000.0   968.0         3          3     0.0         2
# 3  18700000.0   629.0         2          2     1.0         2
# 4  13500000.0  1090.0         2          2     1.0         2
#
#    Furnished_status  type_of_building    Price_sqft
# 0                 1                 1  35612.082671
# 1                 1                 1  35934.291581
# 2                 1                 1  32747.933884
# 3                 1                 1  29729.729730
# 4                 1                 1  12385.321101

# %%
#Removing outliers from the dataset using z-scores
z_scores = np.abs((df - df.mean())/df.std())
threshold = 3
outlier_indices = np.where(z_scores > threshold)
df = df.drop(outlier_indices[0])
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (5257, 9)

# %%
df.to_csv('D:\\house_price_predication_project.csv', index=False)
